# %% [markdown]
# 🟦 CELL 13 — Export Forecast for Power BI

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].to_csv(
    "outputs/forecast.csv", index=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3203310180.py in <cell line: 0>()
# ----> 1 forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].to_csv(
#       2     "outputs/forecast.csv", index=False
#       3 )
#
# NameError: name 'forecast' is not defined

# %% [markdown]
# 🟦 CELL 14 — Save Forecast Plot (for GitHub)

# %%
fig = model.plot(forecast)
fig.savefig("outputs/forecast_plot.png")
